# %%
class E:
    def __init__(self):
        self.name = 'E'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[1-1],v[2-1],v[3-1],v[4-1]]

#########################################
class c2x:
    def __init__(self):
        self.name = 'C2x'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[4-1],v[3-1],v[2-1],v[1-1]]
    
class c2y:
    def __init__(self):
        self.name = 'C2y'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[2-1],v[1-1],v[4-1],v[3-1]]
    
class c2z:
    def __init__(self):
        self.name = 'C2z'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[3-1],v[4-1],v[1-1],v[2-1]]
    
###############################################
class c3_1:
    def __init__(self):
        self.name = 'C3(1)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[1-1],v[4-1],v[2-1],v[3-1]]
    
class c3_2:
    def __init__(self):
        self.name = 'C3(2)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[4-1],v[2-1],v[1-1],v[3-1]]

class c3_3:
    def __init__(self):
        self.name = 'C3(3)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[2-1],v[4-1],v[3-1],v[1-1]]
    
class c3_4:
    def __init__(self):
        self.name = 'C3(4)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[2-1],v[3-1],v[1-1],v[4-1]]
    
###########################################

class c32_1:
    def __init__(self):
        self.name = 'C3^2(1)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[1-1],v[3-1],v[4-1],v[2-1]]

class c32_2:
    def __init__(self):
        self.name = 'C3^2(2)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[3-1],v[2-1],v[4-1],v[1-1]]
    
class c32_3:
    def __init__(self):
        self.name = 'C3^2(3)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[4-1],v[1-1],v[3-1],v[2-1]]
    
class c32_4:
    def __init__(self):
        self.name = 'C3^2(4)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[3-1],v[1-1],v[2-1],v[4-1]]
    
##########################################

class s4x:
    def __init__(self):
        self.name = 's4x'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[3-1],v[1-1],v[4-1],v[2-1]]

class s4y:
    def __init__(self):
        self.name = 's4y'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[4-1],v[1-1],v[2-1],v[3-1]]

class s4z:
    def __init__(self):
        self.name = 's4z'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[4-1],v[3-1],v[1-1],v[2-1]]
    
#################################################
class s34x:
    def __init__(self):
        self.name = 's34x'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[2-1],v[4-1],v[1-1],v[3-1]]

class s34y:
    def __init__(self):
        self.name = 's34y'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[2-1],v[3-1],v[4-1],v[1-1]]
    
class s34z:
    def __init__(self):
        self.name = 's34z'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[3-1],v[4-1],v[2-1],v[1-1]]
    
##############################################

class Gxy:
    def __init__(self):
        self.name = 'Gxy'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[1-1],v[3-1],v[2-1],v[4-1]]

class Gyz:
    def __init__(self):
        self.name = 'Gyz'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[4-1],v[2-1],v[3-1],v[1-1]]

class Gzx:
    def __init__(self):
        self.name = 'Gzx'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[1-1],v[4-1],v[3-1],v[2-1]]

#############################################  
class Gxyp:
    def __init__(self):
        self.name = 'Gxy|'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[3-1],v[2-1],v[1-1],v[4-1]]
    
class Gyzp:
    def __init__(self):
        self.name = 'Gyz|'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[2-1],v[1-1],v[3-1],v[4-1]]
    
class Gzxp:
    def __init__(self):
        self.name = 'Gzx|'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[1-1],v[2-1],v[4-1],v[3-1]]

# %%
E = E()
c2x = c2x()
c2y = c2y()
c2z = c2z()
c3_1 = c3_1()
c3_2 = c3_2()
c3_3 = c3_3()
c3_4 = c3_4()
c32_1 = c32_1()
c32_2 = c32_2()
c32_3 = c32_3()
c32_4 = c32_4()
s4x = s4x()
s4y = s4y()
s4z = s4z()
s34x = s34x()
s34y = s34y()
s34z = s34z()
Gxy = Gxy()
Gyz = Gyz()
Gzx = Gzx()
Gxyp = Gxyp()
Gyzp = Gyzp()
Gzxp = Gzxp()

grupo = [
    E, c2x, c2y, c2z, c3_1, c3_2, c3_3, c3_4,
    c32_1, c32_2, c32_3, c32_4, s4x, s4y, s4z,
    s34x, s34y, s34z, Gxy, Gyz, Gzx, Gxyp, Gyzp, Gzxp
]

# %%
def producto(A,B,group):
    v=A.aplicar(B.id)
    for k in group:
       # print(v," ",k.id," ",k.name)
        if (k.id==v): prod=k
    return prod

# %%
for fila in grupo:
    #print(fila.name,"|",end="\t")
    for columna in grupo:
        print(producto(fila,columna,grupo).name,end="\t")
    print()
# Out:
# E	C2x	C2y	C2z	C3(1)	C3(2)	C3(3)	C3(4)	C3^2(1)	C3^2(2)	C3^2(3)	C3^2(4)	s4x	s4y	s4z	s34x	s34y	s34z	Gxy	Gyz	Gzx	Gxy|	Gyz|	Gzx|
# C2x	E	C2z	C2y	C3^2(2)	C3^2(4)	C3^2(1)	C3^2(3)	C3(3)	C3(1)	C3(4)	C3(2)	s34x	Gxy|	Gyz|	s4x	Gzx	Gzx|	Gyz	Gxy	s34y	s4y	s4z	s34z
# C2y	C2z	E	C2x	C3^2(3)	C3(3)	C3(2)	C3^2(2)	C3^2(4)	C3(4)	C3(1)	C3^2(1)	Gxy	Gzx	s34z	Gyz	Gxy|	s4z	s4x	s34x	s4y	s34y	Gzx|	Gyz|
# C2z	C2y	C2x	E	C3(4)	C3^2(1)	C3^2(4)	C3(1)	C3(2)	C3^2(3)	C3^2(2)	C3(3)	Gyz	s34y	Gzx|	Gxy	s4y	Gyz|	s34x	s4x	Gxy|	Gzx	s34z	s4z
# C3(1)	C3^2(3)	C3(4)	C3^2(2)	C3^2(1)	C2x	C2y	C3(3)	E	C3^2(4)	C3(2)	C2z	Gxy|	s4z	Gyz	s34y	Gyz|	s4x	Gzx	s4y	Gzx|	s34z	s34x	Gxy
# C3(2)	C3^2(1)	C3^2(4)	C3(3)	C2z	C3^2(2)	C3(1)	C2x	C3(4)	E	C2y	C3^2(3)	Gyz|	s4x	s34y	s34z	Gxy	Gzx	s4z	Gzx|	s34x	Gyz	s4y	Gxy|
# C3(3)	C3^2(4)	C3^2(1)	C3(2)	C2x	C3(4)	C3^2(3)	C2z	C3^2(2)	C2y	E	C3(1)	Gzx|	Gxy	Gxy|	s4z	s4x	s4y	s34z	Gyz|	Gyz	s34x	Gzx	s34y
# C3(4)	C3^2(2)	C3(1)	C3^2(3)	C3(2)	C2y	C2x	C3^2(4)	C2z	C3(3)	C3^2(1)	E	Gzx	Gzx|	s4x	s4y	s34z	Gyz	Gxy|	s34y	s4z	Gyz|	Gxy	s34x
# C3^2(1)	C3(2)	C3(3)	C3^2(4)	E	C3^2(3)	C3(4)	C2y	C3(1)	C2z	C2x	C3^2(2)	s34z	Gyz	s4y	Gyz|	s34x	Gxy|	Gzx|	s4z	Gxy	s4x	s34y	Gzx
# C3^2(2)	C3(4)	C3^2(3)	C3(1)	C3(3)	E	C2z	C3^2(1)	C2x	C3(2)	C3^2(4)	C2y	s4y	Gyz|	Gxy	Gzx	s4z	s34x	s34y	Gxy|	s34z	Gzx|	s4x	Gyz
# C3^2(3)	C3(1)	C3^2(2)	C3(4)	C3^2(4)	C2z	E	C3(2)	C2y	C3^2(1)	C3(3)	C2x	s34y	s34z	s34x	Gxy|	Gzx|	Gxy	s4y	Gzx	Gyz|	s4z	Gyz	s4x
# C3^2(4)	C3(3)	C3(2)	C3^2(1)	C2y	C3(1)	C3^2(2)	E	C3^2(3)	C2x	C2z	C3(4)	s4z	s34x	Gzx	Gzx|	Gyz	s34y	Gyz|	s34z	s4x	Gxy	Gxy|	s4y
# s4x	s34x	Gyz	Gxy	Gyz|	Gzx	Gxy|	Gzx|	s4y	s4z	s34z	s34y	C2x	C3(3)	C3(1)	E	C3(2)	C3(4)	C2y	C2z	C3^2(4)	C3^2(1)	C3^2(2)	C3^2(3)
# s4y	Gzx	Gxy|	s34y	s4x	s34z	Gzx|	Gyz	Gyz|	Gxy	s34x	s4z	C3(4)	C2z	C3(3)	C3^2(2)	E	C3^2(1)	C3^2(3)	C3(1)	C2y	C2x	C3(2)	C3^2(4)
# s4z	Gzx|	s34z	Gyz|	Gxy|	s4x	Gxy	s4y	s34x	Gzx	s34y	Gyz	C3(3)	C3^2(2)	C2y	C3^2(4)	C3(1)	E	C3(2)	C3^2(1)	C3(4)	C3^2(3)	C2x	C2z
# s34x	s4x	Gxy	Gyz	s4z	s34y	s4y	s34z	Gxy|	Gyz|	Gzx|	Gzx	E	C3^2(1)	C3^2(2)	C2x	C3^2(4)	C3^2(3)	C2z	C2y	C3(2)	C3(3)	C3(1)	C3(4)
# s34y	Gxy|	Gzx	s4y	Gyz	Gyz|	s4z	s4x	s34z	s34x	Gxy	Gzx|	C3(1)	E	C3^2(4)	C3^2(3)	C2z	C3(2)	C3^2(2)	C3(4)	C2x	C2y	C3^2(1)	C3(3)
# s34z	Gyz|	s4z	Gzx|	s34y	Gxy	s4x	Gzx	Gyz	s4y	Gxy|	s34x	C3(2)	C3(4)	E	C3^2(1)	C3^2(3)	C2y	C3(3)	C3^2(4)	C3^2(2)	C3(1)	C2z	C2x
# Gxy	Gyz	s34x	s4x	Gzx|	s4y	s34y	Gyz|	Gzx	s34z	s4z	Gxy|	C2z	C3(2)	C3^2(3)	C2y	C3(3)	C3^2(2)	E	C2x	C3^2(1)	C3^2(4)	C3(4)	C3(1)
# Gyz	Gxy	s4x	s34x	s34z	Gxy|	Gzx	s4z	s34y	Gzx|	Gyz|	s4y	C2y	C3^2(4)	C3(4)	C2z	C3^2(1)	C3(1)	C2x	E	C3(3)	C3(2)	C3^2(3)	C3^2(2)
# Gzx	s4y	s34y	Gxy|	Gxy	s4z	Gyz|	s34x	Gzx|	s4x	Gyz	s34z	C3^2(2)	C2x	C3(2)	C3(4)	C2y	C3^2(4)	C3(1)	C3^2(3)	E	C2z	C3(3)	C3^2(1)
# Gxy|	s34y	s4y	Gzx	s34x	Gzx|	s34z	Gxy	s4z	Gyz	s4x	Gyz|	C3^2(3)	C2y	C3^2(1)	C3(1)	C2x	C3(3)	C3(4)	C3^2(2)	C2z	E	C3^2(4)	C3(2)
# Gyz|	s34z	Gzx|	s4z	s4y	s34x	Gyz	Gxy|	s4x	s34y	Gzx	Gxy	C3^2(1)	C3(1)	C2z	C3(2)	C3^2(2)	C2x	C3^2(4)	C3(3)	C3^2(3)	C3(4)	E	C2y
# Gzx|	s4z	Gyz|	s34z	Gzx	Gyz	s34x	s34y	Gxy	Gxy|	s4y	s4x	C3^2(4)	C3^2(3)	C2x	C3(3)	C3(4)	C2z	C3^2(1)	C3(2)	C3(1)	C3^2(2)	C2y	E

# %%
# Out:
# E   C2x   C2y   C2z
