# %%
class E:
    def __init__(self):
        self.name = 'E'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[1-1],v[2-1],v[3-1],v[4-1]]

#########################################
class c2x:
    def __init__(self):
        self.name = 'C2x'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[4-1],v[3-1],v[2-1],v[1-1]]
    
class c2y:
    def __init__(self):
        self.name = 'C2y'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[2-1],v[1-1],v[4-1],v[3-1]]
    
class c2z:
    def __init__(self):
        self.name = 'C2z'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[3-1],v[4-1],v[1-1],v[2-1]]
    
###############################################
class c3_1:
    def __init__(self):
        self.name = 'C3(1)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[1-1],v[4-1],v[2-1],v[3-1]]
    
class c3_2:
    def __init__(self):
        self.name = 'C3(2)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[4-1],v[2-1],v[1-1],v[3-1]]

class c3_3:
    def __init__(self):
        self.name = 'C3(3)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[2-1],v[4-1],v[3-1],v[1-1]]
    
class c3_4:
    def __init__(self):
        self.name = 'C3(4)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[2-1],v[3-1],v[1-1],v[4-1]]
    
###########################################

class c32_1:
    def __init__(self):
        self.name = 'C3^2(1)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[1-1],v[3-1],v[4-1],v[2-1]]

class c32_2:
    def __init__(self):
        self.name = 'C3^2(2)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[3-1],v[2-1],v[4-1],v[1-1]]
    
class c32_3:
    def __init__(self):
        self.name = 'C3^2(3)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[4-1],v[1-1],v[3-1],v[2-1]]
    
class c32_4:
    def __init__(self):
        self.name = 'C3^2(4)'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[3-1],v[1-1],v[2-1],v[4-1]]
    
##########################################

class s4x:
    def __init__(self):
        self.name = 's4x'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[3-1],v[1-1],v[4-1],v[2-1]]

class s4y:
    def __init__(self):
        self.name = 's4y'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[4-1],v[1-1],v[2-1],v[3-1]]

class s4z:
    def __init__(self):
        self.name = 's4z'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[4-1],v[3-1],v[1-1],v[2-1]]
    
#################################################
class s34x:
    def __init__(self):
        self.name = 's34x'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[2-1],v[4-1],v[1-1],v[3-1]]

class s34y:
    def __init__(self):
        self.name = 's34y'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[2-1],v[3-1],v[4-1],v[1-1]]
    
class s34z:
    def __init__(self):
        self.name = 's34z'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[3-1],v[4-1],v[2-1],v[1-1]]
    
##############################################

class Gxy:
    def __init__(self):
        self.name = 'Gxy'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[1-1],v[3-1],v[2-1],v[4-1]]

class Gyz:
    def __init__(self):
        self.name = 'Gyz'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[4-1],v[2-1],v[3-1],v[1-1]]

class Gzx:
    def __init__(self):
        self.name = 'Gzx'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[1-1],v[4-1],v[3-1],v[2-1]]

#############################################  
class Gxyp:
    def __init__(self):
        self.name = 'Gxy|'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[3-1],v[2-1],v[1-1],v[4-1]]
    
class Gyzp:
    def __init__(self):
        self.name = 'Gyz|'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[2-1],v[1-1],v[3-1],v[4-1]]
    
class Gzxp:
    def __init__(self):
        self.name = 'Gzx|'
        self.id = self.aplicar([1,2,3,4])

    def aplicar(self,v):
        return [v[1-1],v[2-1],v[4-1],v[3-1]]

# %%
E = E()
c2x = c2x()
c2y = c2y()
c2z = c2z()
c3_1 = c3_1()
c3_2 = c3_2()
c3_3 = c3_3()
c3_4 = c3_4()
c32_1 = c32_1()
c32_2 = c32_2()
c32_3 = c32_3()
c32_4 = c32_4()
s4x = s4x()
s4y = s4y()
s4z = s4z()
s34x = s34x()
s34y = s34y()
s34z = s34z()
Gxy = Gxy()
Gyz = Gyz()
Gzx = Gzx()
Gxyp = Gxyp()
Gyzp = Gyzp()
Gzxp = Gzxp()

grupo = [
    E, c2x, c2y, c2z, c3_1, c3_2, c3_3, c3_4,
    c32_1, c32_2, c32_3, c32_4, s4x, s4y, s4z,
    s34x, s34y, s34z, Gxy, Gyz, Gzx, Gxyp, Gyzp, Gzxp
]

# %%
def producto(A,B,group):
    v=A.aplicar(B.id)
    for k in group:
       # print(v," ",k.id," ",k.name)
        if (k.id==v): prod=k
    return prod

# %%
from IPython.display import HTML, display

def print_table_small(table):
    html = "<table style='font-size:10px; text-align:center; border-collapse:collapse;'>"
    for row in table:
        html += "<tr>" + "".join(f"<td style='border:1px solid black;'>{cell}</td>" for cell in row) + "</tr>"
    html += "</table>"
    display(HTML(html))

table = [
    [producto(fila, columna, grupo).name for columna in grupo]
    for fila in grupo
]

print_table_small(table)
# Out:
# <table style='font-size:10px; text-align:center; border-collapse:collapse;'><tr><td style='border:1px solid black;'>E</td><td style='border:1px solid black;'>C2x</td><td style='border:1px solid black;'>C2y</td><td style='border:1px solid black;'>C2z</td><td style='border:1px solid black;'>C3(1)</td><td style='border:1px solid black;'>C3(2)</td><td style='border:1px solid black;'>C3(3)</td><td style='border:1px solid black;'>C3(4)</td><td style='border:1px solid black;'>C3^2(1)</td><td style='border:1px solid black;'>C3^2(2)</td><td style='border:1px solid black;'>C3^2(3)</td><td style='border:1px solid black;'>C3^2(4)</td><td style='border:1px solid black;'>s4x</td><td style='border:1px solid black;'>s4y</td><td style='border:1px solid black;'>s4z</td><td style='border:1px solid black;'>s34x</td><td style='border:1px solid black;'>s34y</td><td style='border:1px solid black;'>s34z</td><td style='border:1px solid black;'>Gxy</td><td style='border:1px solid black;'>Gyz</td><td style='bo
# ...
